# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Philip Shanley** <br>
# I am a Mechanical Engineer.

# %% [markdown]
# *I am very curious with the idea of finding patterns and predictions to problems hiding in available data :)*

# %% [markdown]
# #### Simple seaborn scatter heatmap with fictional data

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

randData1=np.random.rand(50)
randData2=np.random.rand(50)
randData3=np.random.rand(50)
randData4=np.random.rand(50)

plt.figure(figsize=(5,5),dpi=100)
sns.scatterplot(data=[randData1,randData2,randData3,randData4])
# Out:
# <AxesSubplot:>

# %% [markdown]
# -[HyperLink](https://www.coursera.org/)
# ~~Strikethrough~~
